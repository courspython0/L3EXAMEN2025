# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression,Ridge,Lasso,LassoCV
from sklearn.metrics import mean_squared_error, r2_score,mean_absolute_error
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score,mean_absolute_error
from sklearn.model_selection import cross_val_score


df = pd.read_csv(r'C:/examPy_Defense/bdd/bddBostonNettoyer_sans_aberrante.csv')




""""
    ALPHA = 0.6 , permet de rendre le point transparants , utile si il y a beaucoup
    de données"y
"""
# Out:
# '"\n    ALPHA = 0.6 , permet de rendre le point transparants , utile si il y a beaucoup\n    de données"y\n'

# %%
"""RELATION ENTRE  LES  PRIX ET NOMBRE DE PIECES"""

plt.scatter(x = df['NBR_MOYEN_PIECES'], y = df['PRIX_DU_LOGEMENT'], alpha = 0.6)
plt.title('RELATION ENTRE  LES  PRIX ET NOMBRE DE PIECES')
plt.xlabel('NOMBRE DES PIECES')
plt.ylabel('PRIX DES LOGEMENT')
plt.show()

# %%
"""RELATION ENTRE  LES  PRIX ET TAUX DE CRIMINALITE"""

plt.scatter(x = df['TAUX_DE_CRIMINALITE'], y = df['PRIX_DU_LOGEMENT'], alpha = 0.6)
plt.title('RELATION ENTRE  LES PRIX ET TAUX DE CRIMINALITE')
plt.xlabel('TAUX DE CRIMINALITE')
plt.ylabel('PRIX DES LOGEMENT')
plt.show()

# %%
"""RELATION ENTRE  LES  PRIX ET zonage residentiel"""

plt.scatter(x = df['zonage_residentiel'], y = df['PRIX_DU_LOGEMENT'], alpha = 0.6)
plt.title('RELATION ENTRE  LES PRIX ET zonage residentiel')
plt.xlabel('zonage residentiel')
plt.ylabel('PRIX DES LOGEMENT')
plt.show()

# %%
"""RELATION ENTRE  LES  PRIX ET LA PROPORTION INDUSTRIELLE"""

plt.scatter(x = df['PROPORTION_INDUSTRIELLE'], y = df['PRIX_DU_LOGEMENT'], alpha = 0.6)
plt.title('RELATION ENTRE  LES PRIX ET PROPORTION INDUSTRIELLE')
plt.xlabel('PROPORTION INDUSTRIELLE')
plt.ylabel('PRIX DES LOGEMENT')
plt.show()

# %%
"""RELATION ENTRE  LES  PRIX ET LA CONCENTRATION NOX"""

plt.scatter(x = df['CONCENTRATION_NOX'], y = df['PRIX_DU_LOGEMENT'],alpha = 0.6)
plt.title('RELATION ENTRE  LES PRIX ET CONCENTRATION NOX')
plt.xlabel('CONCENTRATION NOX')
plt.ylabel('PRIX DES LOGEMENT')
plt.show()

# %%
"""RELATION ENTRE  LES  PRIX ET DISTENCE ENTREPRISES"""

plt.scatter(x = df['DISTENCE_ENTREPRISES'], y = df['PRIX_DU_LOGEMENT'],alpha = 0.6)
plt.title('RELATION ENTRE  LES PRIX ET DISTENCE ENTREPRISES')
plt.xlabel('DISTENCE ENTREPRISES')
plt.ylabel('PRIX DES LOGEMENT')
plt.show()

# %%
"""RELATION ENTRE  LES  PRIX ET L'ACCES_AUTOROUTE"""

plt.scatter(x = df['ACCES_AUTOROUTE'], y = df['PRIX_DU_LOGEMENT'],alpha = 0.6)
plt.title('RELATION ENTRE  LES PRIX ET ACCES AUTOROUTE')
plt.xlabel('ACCES AUTOROUTE')
plt.ylabel('PRIX DES LOGEMENT')
plt.show()

# %%
"""RELATION ENTRE  LES  PRIX ET LE TAUX TAXE FONCIERE"""

plt.scatter(x = df['TAUX_TAXE_FONCIERE'], y = df['PRIX_DU_LOGEMENT'],alpha = 0.6)
plt.title('RELATION ENTRE  LES PRIX ET LE TAUX TAXE FONCIERE')
plt.xlabel('TAUX TAXE FONCIERE')
plt.ylabel('PRIX DES LOGEMENT')
plt.show()

# %%
"""RELATION ENTRE  LES  PRIX ET LA RATION ELEVE ENSEIGNANT"""

plt.scatter(x = df['RATION_ELEVE_ENSEIGNANT'], y = df['PRIX_DU_LOGEMENT'],alpha = 0.6)
plt.title('RELATION ENTRE  LES PRIX ET LA RATION ELEVE ENSEIGNANT')
plt.xlabel('RATION ELEVE ENSEIGNANT')
plt.ylabel('PRIX DES LOGEMENT')
plt.show()

# %%
"""RELATION ENTRE  LES  PRIX ET LA DEMOGRAPHIE MINORITAIRE"""

plt.scatter(x = df['DEMOGRAPHIE_MINORITAIRE'], y = df['PRIX_DU_LOGEMENT'],alpha = 0.6)
plt.title('RELATION ENTRE  LES PRIX ET LA DEMOGRAPHIE MINORITAIRE')
plt.xlabel('DEMOGRAPHIE MINORITAIRE')
plt.ylabel('PRIX DES LOGEMENT')
plt.show()

# %%
"""RELATION ENTRE  LES  PRIX ET LE  STATUT SOCIO ECONOMIQUE_INFERIEUR"""

plt.scatter(x = df['STATUT_SOCIO_ECONOMIQUE_INFERIEUR'], y = df['PRIX_DU_LOGEMENT'],alpha = 0.6)
plt.title('RELATION ENTRE  LES PRIX ET LE STATUT SOCIO ECONOMIQUE_INFERIEUR')
plt.xlabel('STATUT SOCIO ECONOMIQUE_INFERIEUR')
plt.ylabel('PRIX DES LOGEMENT')
plt.show()

# %%
"""
    un nuage de points permet de voir directement comment les prix 
    varient en focntion de la variable x, permettant de repérer 
    les tendances, les concentrations de données
    
"""
# Out:
# '\n    un nuage de points permet de voir directement comment les prix \n    varient en focntion de la variable x, permettant de repérer \n    les tendances, les concentrations de données\n\n'
